# %% [markdown]
# ### Query NYT API
# Determine how to get the top stories for New York Times

# %%
import requests
from secrets import api_key

# %%
queryUrl = f"https://api.nytimes.com/svc/search/v2/articlesearch.json?q=election&api-key={api_key}"

# %%
queryUrl = f"https://api.nytimes.com/svc/search/v2/articlesearch.json?&api-key={api_key}"

# %%
queryUrl
# Out:
# 'https://api.nytimes.com/svc/search/v2/articlesearch.json?q=election&api-key=INkNRdIv71fjEKrCAXCPxqAMyxZBKzNV'

# %%
#queryFilter = "fq=source:('The New York Times')"

#queryFilter = 'fq=news_desk:("Technology" "Business") AND pub_date:(2019-07-01)'


#queryFilter = 'fq=news_desk:("Technology") AND pub_date:(2019-07-01)'


queryFilter = 'fq=news_desk:("Business" "Business Day" "Technology" "Personal Tech" "Politics" ) AND pub_date:(2019-07-01)'


#queryFilter = 'fq=news_desk:("Jobs") AND pub_date:(2019-07-01)'


queryUrl = f"https://api.nytimes.com/svc/search/v2/articlesearch.json?{queryFilter}&api-key={api_key}"

queryUrl
# Out:
# 'https://api.nytimes.com/svc/search/v2/articlesearch.json?fq=news_desk:("Jobs") AND pub_date:(2019-07-01)&api-key=INkNRdIv71fjEKrCAXCPxqAMyxZBKzNV'

# %% [markdown]
# Found that there are not that many articles with all of the different news desks for an individual day.

# %%
articles = requests.get(queryUrl).json()

articles
# Out:
# {'status': 'OK',
#  'copyright': 'Copyright (c) 2019 The New York Times Company. All Rights Reserved.',
#  'response': {'docs': [{'web_url': 'https://www.nytimes.com/2019/07/01/business/global-markets.html',
#     'snippet': 'Markets took heart in the resumption of negotiations between Washington and Beijing. Still, many doubt the two sides can reach a deal anytime soon.',
#     'lead_paragraph': 'HONG KONG — Shares in technology companies led Wall Street stocks higher on Monday, with global investors buoyed by a thaw in the trade dispute between the United States and China even as prospects for a long-term deal remained uncertain.',
#     'abstract': 'Markets took heart in the resumption of negotiations between Washington and Beijing. Still, many doubt the two sides can reach a deal anytime soon.',
#     'blog': {},
#     'source': 'The New York Times',
#     'multimedia': [{'rank': 0,
#       'subtype': 'xlarge',
#       'caption': None,
#       'credit': None,
# ...

# %%
articles
# Out:
# {'status': 'OK',
#  'copyright': 'Copyright (c) 2019 The New York Times Company. All Rights Reserved.',
#  'response': {'docs': [{'web_url': 'https://www.nytimes.com/2014/06/24/sports/worldcup/world-cup-2014-us-still-sorting-through-emotions-after-last-second-draw-with-portugal.html',
#     'snippet': 'The United States soccer team and its fans were still sorting through their emotions after a stunning last-second draw with Portugal on Sunday.',
#     'lead_paragraph': 'MANAUS, Brazil — Andy Smith stood among a throng of American fans Sunday night, checking the stopwatch on his smartphone, thinking surely this game would end in ecstatic victory.',
#     'abstract': 'The United States soccer team and its fans were still sorting through their emotions after a stunning last-second draw with Portugal on Sunday.',
#     'print_page': '10',
#     'blog': {},
#     'source': 'The New York Times',
#     'multimedia': [{'rank': 0,
#       'subtype': 'wide',
#       'caption': None,
# ...
